# %%
import pandas as pd
import timeit

# %%
start = timeit.default_timer()

# %%
df1 = pd.read_csv('data/dr1603.csv')
df2 = pd.read_csv('data/dr1535.csv')
df3 = pd.read_csv('data/dr1635.csv')
df4 = pd.read_csv('data/dr1457.csv')
df5 = pd.read_csv('data/dr1557.csv')
df6 = pd.read_csv('data/dr1657.csv')

# %%
out = df1.append(df2)
out = out.append(df3)
out = out.append(df4)
out = out.append(df5)
out = out.append(df6)

# %%
print(out)
# Out:
#                     objid  modelMag_u  modelMag_g  modelMag_r  modelMag_i  \
# 0     1237646798136804903    22.70128    21.55564    20.74338    19.97239
# 1     1237646798136805020    23.23910    21.44343    19.67306    18.94400
# 2     1237646798136805140    24.05348    21.24721    19.39289    18.68024
# 3     1237646798136870225    26.32478    20.74059    18.99681    18.29084
# 4     1237646798136934932    24.76801    19.32076    17.81846    17.23835
# ...                   ...         ...         ...         ...         ...
# 6336  1237680277409890749    23.95901    21.45168    20.99064    20.83455
# 6337  1237680284388295297    26.08886    22.08654    21.42736    21.39464
# 6338  1237680332716049516    24.30561    23.59575    21.74487    20.60606
# 6339  1237680481954366063    25.70489    22.18283    21.30940    20.22876
# 6340  1237680503437525616    21.34051    20.64733    20.40584    20.45839
#
#       modelMag_z  fiberMag_u  fiberMag_g  fiberMag_r  fiberMag_i  fiberMag_z  \
# ...

# %%
out.to_csv('data/train.csv')
stop = timeit.default_timer()
print('Time: ', (stop - start)/60,'minutes')
# Out:
# Time:  0.5488194016666667 minutes
